#####.#...#
.##...####.
.###...##.#
.....#.....
.....#..#..
##..#..#..#
..###..##..
#####.####.
##...#..##.
..#.#.....#
..#.#.....#
##...#..##.
#####.####.
..###..##..
##..#..#..#
.....#..#..
.....#.....

.##.....####..#
.....#........#
#..#.####..####
####...#.##.#..
####.#.######.#
....##...##...#
####.#.#.##.#.#
......#.#..#.#.
#..####......##
####...######..
#..####..##..##
#..##.#.####.#.
......##.##.##.

##.########
##.########
.#..##.##.#
##.#.######
....##.##.#
#.###..##..
..##...##..
..#####..##
#.#.#######
..##.#.##.#
....#......
.#####....#
#.#.#..##..
.#.##.#..#.
#.#....##..
.#.####...#
#..##......

.#....#.#####.#.#
#.#...##..###.###
#.##.#..##..##..#
.....#.###.#...##
.##..#....###.#..
.#..#...#..#.#.#.
.#..#.#..#.##.###
.#..#.#..#.##.###
.#..#...#..#.#...
.##..#....###.#..
.....#.###.#...##
#.##.#..##..##..#
#.#...##..###.###
.#....#.#####.#.#
.#....#.#####.#.#

##..##...
###.##...
#.###..#.
#.###..#.
###.##...
##..##...
#....#...
#####..#.
##..#####
#.##..#.#
.###.#.#.
###.###.#
...###..."""

_data = """#.##..##.
..#.##.#.
##......#
##......#
..#.##.#.
..##..##.
#.#.##.#.

#...##..#
#....#..#
..##..###
#####.##.
#####.##.
..##..###
#....#..#"""

_data = """#.#.....#.##.##.#
#.#.....#.##.##.#
.....#...#####...
...#.###....#...#
.###..####.#..#.#
#.###.#.#..###..#
..####...##.#.##.
..####...##.#.##.
#.#.#.#.#..###..#
.###..####.#..#.#
...#.###....#...#
.....#...#####...
#.#.....#.##.##.#"""


def find_smudge_hor(block, tposed):
    block = block.splitlines()
    for idx, _ in enumerate(block[:-1]):
        flipped = zip(block[: idx + 1][::-1], block[idx + 1 :])

        diffs = [[0 if a == b else 1 for a, b in zip(a, b)] for a, b in flipped]
        sum_diffs = sum([sum(d) for d in diffs])
        if sum_diffs == 1:
            x, y = [
                (c, r)
                for c, row in enumerate(diffs)
                for r, val in enumerate(row)
                if val == 1
            ][0]
            x = idx - x
            if tposed:
                x, y = y, x
            return (x, y)


def find_smudge(block):
    hor = find_smudge_hor(block, tposed=False)
    block = transpose(block)
    ver = find_smudge_hor(block, tposed=True)
    return hor or ver


def clean_smudge(block):
    sm_x, sm_y = find_smudge(block)
    block = [list(row) for row in block.splitlines()]
    block[sm_x][sm_y] = FLIP[block[sm_x][sm_y]]
    block = "\n".join(["".join(row) for row in block])
    return block, (sm_x, sm_y)


def find_axis_hor(block):
    block = block.splitlines()
    axes = []
    for idx, _ in enumerate(block[:-1]):
        flipped = zip(block[: idx + 1][::-1], block[idx + 1 :])
        if all([a == b for a, b in flipped]):
            axes.append(idx + 1)
    return axes


def find_axis(block):
    hor = find_axis_hor(block)
    block = transpose(block)
    ver = find_axis_hor(block)
    return {"hor": hor, "ver": ver}


def mirror_score(scores):
    rows = sum([row * 100 for row in scores["hor"]])
    cols = sum([col for col in scores["ver"]])
    return rows + cols


FLIP = {"#": ".", ".": "#"}

data = data.split("\n\n")
print(data)

scores = []
for idx, block in enumerate(data):
    # print(block)
    print()
    axis_old = find_axis(block)
    block, smudge = clean_smudge(block)
    axis_new = find_axis(block)
    axis_diff = {key: set(axis_new[key]) - set(axis_old[key]) for key in axis_new}
    score = mirror_score(axis_diff)
    scores.append(score)
    print("idx:", idx)
    print("old:", axis_old)
    print("smudge:", smudge)
    print("new:", axis_new)
    print("diff:", axis_diff)
    print("score:", score)
    print("\n\n")


print(scores)
print(sum(scores))
# Out:
# ['##...######...##.\n......#..#.......\n##.##########.###\n###..........###.\n...#..#..#..#...#\n##..###..###..###\n..##.#.##.#.##..#\n..####.##.####..#\n####........####.\n..#.##.##.##.#..#\n##.###.##.###.###\n###.#......#.####\n......####......#\n#..#.##..##.#..##\n..#.########.#...\n##...######...##.\n..#.##....##.#..#', '...##......#.\n...#.......#.\n#......##.###\n.##########.#\n#####.###.##.\n###.####.##..\n###.####.##..\n#####.###.##.\n.##########.#', '#.##..#\n##.#.#.\n##.#.##\n#.##..#\n...####\n#.#..#.\n#.#..#.', '.##.#..\n.##.###\n..#####\n#..####\n.####..\n.#...##\n##...##', '#.#.....#.##.##.#\n#.#.....#.##.##.#\n.....#...#####...\n...#.###....#...#\n.###..####.#..#.#\n#.###.#.#..###..#\n..####...##.#.##.\n..####...##.#.##.\n#.#.#.#.#..###..#\n.###..####.#..#.#\n...#.###....#...#\n.....#...#####...\n#.#.....#.##.##.#', '###.####.#..#\n#...##.##..#.\n.#.##.#.###.#\n.#..#.#.###.#\n#.#...##.#.##\n##.#..##.#..#\n##.#...#.#..#\n#.#...##.#.##\n.#..#.#.###.#\n.#.##.#.###.#\n#...##.##..#.\n###.####.#..#\n#..#..#..#.##\n.#...#.#..#.#\n.#...#.#..#.#\n#..#..#..#.##\n###.####.#..#', '.#.#..#..\n..#.##.#.\n..#.##.#.\n##.#..#..\n.#.#.#.##\n...#...##\n...#...##', '.#......#..##.###\n.###..###.##.####\n.##....##.#####.#\n#.######.##...##.\n##.#..#.##.###..#\n#...##...#.#.###.\n..##..##.........\n#..####.###....#.\n.#.####.#.#####..\n.##....##.##..##.\n###.##.####....##\n#..#..#..#..##...\n#..####..#####...\n#..####..#####...\n#..#..#..#..##...', '...#....#\n###.####.\n###....#.\n.#..####.\n..##.##.#\n#####..##\n#..######\n#####..##\n.###.##.#\n..##....#\n..##....#\n..##....#\n..##....#\n.###.##.#\n#####..##', '#.##...##.#\n##..#####..\n##..##.#.#.\n.####......\n#.##.###...\n..##....###\n##..####...\n##..####...\n..##....###\n#.##.###...\n.####......\n##..##.#.#.\n##..#####..', '..###...#\n..###...#\n.#..##.##\n.###....#\n...####.#\n..###.#.#\n#.#..#.#.\n#.#..#.#.\n..###.###\n...####.#\n.###....#\n.#..##.##\n..###...#', '...#..#.###....\n#.#....#..#....\n..##......##.#.\n##.#.####.#.###\n##..##.#..###.#\n#######...##..#\n..#.#...###.#..\n..#####..######\n###.##..#..####\n##.######..#...\n##.######..#...\n###.##..#..####\n..#####..######\n..#.#...###.#..\n#######...##..#', '#.##.##\n#.##.##\n..###.#\n..###.#\n..####.\n......#\n.....#.\n.#..##.\n.#..##.\n.....#.\n......#\n..####.\n..###.#\n..###.#\n#.#####', '##..#..#.\n..###..##\n###.###..\n###......\n....#..#.\n...#.##.#\n.....##..\n##...##..\n##.#....#', '.#..#.##..##.#..#\n#.#...##..##...#.\n#.#...##..##...#.\n.#..#.##..##.#..#\n.###....##....###\n###..#..##..#..##\n#.#...######...#.\n...##...##..###..\n#...#.######.#...', '..#..#....#.###\n#.####....#..##\n###..###..#....\n.#.##.#....##..\n#......#...##..\n.#.##.#..###.##\n..#..#..#.#.#..\n.######.#.#..##\n###..####..####\n##.##.###......\n...##...###....', '###..###..#####..\n.#...#.....##....\n.##............#.\n####...#.####....\n#....#.#.##.#..#.\n##....#.#.#..#..#\n#.#.###..#..#..##\n#.#.###.##..#..##\n##....#.#.#..#..#\n##....#.#.#..#..#\n#.#.###.##..#..##\n#.#.###..#..#..##\n##....#.#.#..#..#', '##..#..#.#.##.#\n##.#.#.#...####\n####..##...#.#.\n..##.#....#.#..\n..##.#....#.#..\n###...##...#.#.\n##.#.#.#...####\n##..#..#.#.##.#\n#######.###...#', '....#.##..#..#.\n#..###.....##..\n#..#.###.##..##\n#######.##.##.#\n.##..#....####.\n....##..#......\n####..#.#.#..#.\n..#.####.##..##\n.##...##.#.##.#\n....#..#.##..##\n.....#..#.####.\n.##..##....##..\n....#.##...##..', '##....#....##\n.....###.####\n.####....##.#\n.####....##.#\n.....###.####\n##....#....##\n.....#.###...\n###.#.#...###\n###.#.#...###\n.....#.###...\n##....#.....#', '############.##\n#..######..#.##\n#...####...####\n...######......\n#.###..###.#.##\n#..##..##..####\n.###....###.###\n#.#......#.#.##\n..########..##.', '......#\n####.##\n.##.#..\n#..###.\n....##.\n###.#..\n#####..\n#####..\n###.#..\n....##.\n#..###.\n.##.#..\n####.##\n......#\n....#.#\n....###\n....#.#', '.#.##.###.#..\n.#...#.#...##\n.##..#####...\n.##..#####...\n.#...#.#...##\n##.##.###.#..\n ...
#
# idx: 0
# old: {'hor': [], 'ver': [8]}
# smudge: (13, 0)
# new: {'hor': [], 'ver': [1]}
# diff: {'hor': set(), 'ver': {1}}
# score: 1
#
#
#
#
# idx: 1
# old: {'hor': [6], 'ver': []}
# smudge: (0, 4)
# new: {'hor': [1, 6], 'ver': []}
# diff: {'hor': {1}, 'ver': set()}
# score: 100
#
#
#
#
# idx: 2
# old: {'hor': [6], 'ver': []}
# smudge: (1, 6)
# new: {'hor': [2, 6], 'ver': []}
# diff: {'hor': {2}, 'ver': set()}
# score: 200
#
#
#
#
# idx: 3
# old: {'hor': [], 'ver': [6]}
# smudge: (5, 0)
# new: {'hor': [6], 'ver': [6]}
# diff: {'hor': {6}, 'ver': set()}
# score: 600
#
#
#
#
# idx: 4
# old: {'hor': [1], 'ver': []}
# smudge: (5, 3)
# new: {'hor': [1, 7], 'ver': []}
# diff: {'hor': {7}, 'ver': set()}
# score: 700
#
#
#
#
# idx: 5
# old: {'hor': [14], 'ver': []}
# smudge: (5, 6)
# new: {'hor': [6, 14], 'ver': []}
# diff: {'hor': {6}, 'ver': set()}
# score: 600
#
#
#
#
# idx: 6
# old: {'hor': [6], 'ver': []}
# smudge: (0, 0)
# new: {'hor': [2, 6], 'ver': []}
# diff: {'hor': {2}, 'ver': set()}
# score: 200
#
#
#
#
# idx: 7
# old: {'hor': [13], 'ver': []}
# smudge: (7, 1)
# new: {'hor': [13], 'ver': [5]}
# diff: {'hor': set(), 'ver': {5}}
# score: 5
#
#
#
#
# idx: 8
# old: {'hor': [11], 'ver': []}
# smudge: (2, 4)
# new: {'hor': [11], 'ver': [6]}
# diff: {'hor': set(), 'ver': {6}}
# score: 6
#
#
#
#
# idx: 9
# old: {'hor': [7], 'ver': []}
# smudge: (0, 0)
# new: {'hor': [7], 'ver': [3]}
# diff: {'hor': set(), 'ver': {3}}
# score: 3
#
#
#
#
# idx: 10
# old: {'hor': [1], 'ver': []}
# smudge: (5, 7)
# new: {'hor': [1, 7], 'ver': []}
# diff: {'hor': {7}, 'ver': set()}
# score: 700
#
#
#
#
# idx: 11
# old: {'hor': [10], 'ver': []}
# smudge: (1, 0)
# new: {'hor': [10], 'ver': [1]}
# diff: {'hor': set(), 'ver': {1}}
# score: 1
#
#
#
#
# idx: 12
# old: {'hor': [1], 'ver': []}
# smudge: (1, 4)
# new: {'hor': [8], 'ver': []}
# diff: {'hor': {8}, 'ver': set()}
# score: 800
#
#
#
#
# idx: 13
# old: {'hor': [], 'ver': [1]}
# smudge: (2, 4)
# new: {'hor': [], 'ver': [1, 6]}
# diff: {'hor': set(), 'ver': {6}}
# score: 6
#
#
#
#
# idx: 14
# old: {'hor': [2], 'ver': []}
# smudge: (7, 5)
# new: {'hor': [2], 'ver': [9]}
# diff: {'hor': set(), 'ver': {9}}
# score: 9
#
#
#
#
# idx: 15
# old: {'hor': [], 'ver': [14]}
# smudge: (1, 0)
# new: {'hor': [], 'ver': [4, 14]}
# diff: {'hor': set(), 'ver': {4}}
# score: 4
#
#
#
#
# idx: 16
# old: {'hor': [9], 'ver': []}
# smudge: (10, 8)
# new: {'hor': [11], 'ver': []}
# diff: {'hor': {11}, 'ver': set()}
# score: 1100
#
#
#
#
# idx: 17
# old: {'hor': [], 'ver': [1]}
# smudge: (2, 3)
# new: {'hor': [4], 'ver': [1]}
# diff: {'hor': {4}, 'ver': set()}
# score: 400
#
#
#
#
# idx: 18
# old: {'hor': [], 'ver': [12]}
# smudge: (7, 1)
# new: {'hor': [], 'ver': [2, 12]}
# diff: {'hor': set(), 'ver': {2}}
# score: 2
#
#
#
#
# idx: 19
# old: {'hor': [3], 'ver': []}
# smudge: (5, 11)
# new: {'hor': [8], 'ver': []}
# diff: {'hor': {8}, 'ver': set()}
# score: 800
#
#
#
#
# idx: 20
# old: {'hor': [], 'ver': [6]}
# smudge: (8, 13)
# new: {'hor': [], 'ver': [6, 14]}
# diff: {'hor': set(), 'ver': {14}}
# score: 14
#
#
#
#
# idx: 21
# old: {'hor': [7], 'ver': []}
# smudge: (15, 5)
# new: {'hor': [7, 16], 'ver': []}
# diff: {'hor': {16}, 'ver': set()}
# score: 1600
#
#
#
#
# idx: 22
# old: {'hor': [], 'ver': [12]}
# smudge: (0, 0)
# new: {'hor': [3], 'ver': [12]}
# diff: {'hor': {3}, 'ver': set()}
# score: 300
#
#
#
#
# idx: 23
# old: {'hor': [], 'ver': [14]}
# smudge: (3, 0)
# new: {'hor': [5], 'ver': [14]}
# diff: {'hor': {5}, 'ver': set()}
# score: 500
#
#
#
#
# idx: 24
# old: {'hor': [1], 'ver': []}
# smudge: (9, 2)
# new: {'hor': [1, 10], 'ver': []}
# diff: {'hor': {10}, 'ver': set()}
# score: 1000
#
#
#
#
# idx: 25
# old: {'hor': [6], 'ver': []}
# smudge: (2, 4)
# new: {'hor': [6], 'ver': [6]}
# diff: {'hor': set(), 'ver': {6}}
# score: 6
#
#
#
#
# idx: 26
# old: {'hor': [], 'ver': [10]}
# smudge: (9, 3)
# new: {'hor': [], 'ver': [5, 10]}
# diff: {'hor': set(), 'ver': {5}}
# score: 5
#
#
#
#
# idx: 27
# old: {'hor': [], 'ver': [14]}
# smudge: (0, 4)
# new: {'hor': [], 'ver': [7, 14]}
# diff: {'hor': set(), 'ver': {7}}
# score: 7
#
#
#
#
# idx: 28
# old: {'hor': [], 'ver': [16]}
# smudge: (5, 0)
# new: {'hor': [6], 'ver': [16]}
# diff: {'hor': {6}, 'ver': set()}
# score: 600
#
#
#
#
# idx: 29
# old: {'hor': [14], 'ver': []}
# smudge: (2, 13)
# new: {'hor': [7, 14], 'ver': []}
# diff: {'hor': {7}, 'ver': set()}
# score: 700
#
#
#
#
# idx: 30
# old: {'hor': [], 'ver': [2]}
# smudge: (7, 4)
# new: {'hor': [8], 'ver': [2]}
# diff: {'hor': {8}, 'ver': set()}
# score: 800
#
#
#
#
# idx: 31
# old: {'hor': [], 'ver': [5]}
# smudge: (6, 12)
# new: {'hor': [], 'ver': [5, 13]}
# diff: {'hor': set(), 'ver': {13}}
# score: 13
#
#
#
#
# idx: 32
# old: {'hor': [], 'ver': [1]}
# smudge: (5, 5)
# new: {'hor': [], 'ver': [1, 6]}
# diff: {'hor': set(), 'ver': {6}}
# score: 6
#
#
#
#
# idx: 33
# old: {'hor': [10], 'ver': []}
# smudge: (0, 5)
# new: {'hor': [2, 10], 'ver': []}
# diff: {'hor': {2}, 'ver': set()}
# score: 200
#
#
#
#
# idx: 34
# old: {'hor': [], 'ver': [10]}
# smudge: (8, 11)
# new: {'hor': [], 'ver': [12]}
# diff: {'hor': set(), 'ver': {12}}
# score: 12
#
#
#
#
# idx: 35
# old: {'hor': [4], 'ver': []}
# smudge: (9, 3)
# new: {'hor': [4, 10], 'ver': []}
# diff: {'hor': {10}, 'ver': set()}
# score: 1000
#
#
#
#
# idx: 36
# old: {'hor': [11], 'ver': []}
# smudge: (0, 5)
# new: {'hor': [11], 'ver': [6]}
# diff: {'hor': set(), 'ver': {6}}
# score: 6
#
#
#
#
# idx: 37
# old: {'hor': [], 'ver': [5]}
# smudge: (6, 0)
# new: {'hor': [], 'ver': [2, 5]}
# diff: {'hor': set(), 'ver': {2}}
# score: 2
#
#
#
#
# idx: 38
# old: {'hor': [], 'ver': [4]}
# smudge: (7, 0)
# new: {'hor': [], 'ver': [2]}
# diff: {'hor': set(), 'ver': {2}}
# score: 2
#
#
#
#
# idx: 39
# old: {'hor': [12], 'ver': []}
# smudge: (1, 4)
# new: {'hor': [12], 'ver': [8]}
# diff: {'hor': set(), 'ver': {8}}
# score: 8
#
#
#
#
# idx: 40
# old: {'hor': [], 'ver': [10]}
# smudge: (12, 1)
# new: {'hor': [13], 'ver': [10]}
# diff: {'hor': {13}, 'ver': set()}
# score: 1300
#
#
#
#
# idx: 41
# old: {'hor': [], 'ver': [9]}
# smudge: (14, 1)
# new: {'hor': [], 'ver': [2, 9]}
# diff: {'hor': set(), 'ver': {2}}
# score: 2
#
#
#
#
# idx: 42
# old: {'hor': [], 'ver': [1]}
# smudge: (7, 9)
# new: {'hor': [9], 'ver': [1]}
# diff: {'hor': {9}, 'ver': set()}
# score: 900
#
#
#
#
# idx: 43
# old: {'hor': [], 'ver': [3]}
# smudge: (7, 5)
# new: {'hor': [], 'ver': [6]}
# diff: {'hor': set(), 'ver': {6}}
# score: 6
#
#
#
#
# idx: 44
# old: {'hor': [9], 'ver': []}
# smudge: (3, 3)
# new: {'hor': [9], 'ver': [8]}
# diff: {'hor': set(), 'ver': {8}}
# score: 8
#
#
#
#
# idx: 45
# old: {'hor': [], 'ver': [9]}
# smudge: (10, 3)
# new: {'hor': [], 'ver': [4, 9]}
# diff: {'hor': set(), 'ver': {4}}
# score: 4
#
#
#
#
# idx: 46
# old: {'hor': [15], 'ver': []}
# smudge: (0, 8)
# new: {'hor': [3, 15], 'ver': []}
# diff: {'hor': {3}, 'ver': set()}
# score: 300
#
#
#
#
# idx: 47
# old: {'hor': [], 'ver': [10]}
# smudge: (3, 0)
# new: {'hor': [], 'ver': [1, 10]}
# diff: {'hor': set(), 'ver': {1}}
# score: 1
#
#
#
#
# idx: 48
# old: {'hor': [2], 'ver': []}
# smudge: (13, 3)
# new: {'hor': [2, 14], 'ver': []}
# diff: {'hor': {14}, 'ver': set()}
# score: 1400
#
#
#
#
# idx: 49
# old: {'hor': [1], 'ver': []}
# smudge: (9, 3)
# new: {'hor': [1, 10], 'ver': []}
# diff: {'hor': {10}, 'ver': set()}
# score: 1000
#
#
#
#
# idx: 50
# old: {'hor': [16], 'ver': []}
# smudge: (9, 13)
# new: {'hor': [16], 'ver': [15]}
# diff: {'hor': set(), 'ver': {15}}
# score: 15
#
#
#
#
# idx: 51
# old: {'hor': [], 'ver': [12]}
# smudge: (1, 6)
# new: {'hor': [7], 'ver': [12]}
# diff: {'hor': {7}, 'ver': set()}
# score: 700
#
#
#
#
# idx: 52
# old: {'hor': [], 'ver': [3]}
# smudge: (2, 6)
# new: {'hor': [5], 'ver': [3]}
# diff: {'hor': {5}, 'ver': set()}
# score: 500
#
#
#
#
# idx: 53
# old: {'hor': [12], 'ver': []}
# smudge: (2, 14)
# new: {'hor': [3, 12], 'ver': []}
# diff: {'hor': {3}, 'ver': set()}
# score: 300
#
#
#
#
# idx: 54
# old: {'hor': [8], 'ver': []}
# smudge: (9, 11)
# new: {'hor': [11], 'ver': []}
# diff: {'hor': {11}, 'ver': set()}
# score: 1100
#
#
#
#
# idx: 55
# old: {'hor': [], 'ver': [4]}
# smudge: (1, 8)
# new: {'hor': [2], 'ver': [4]}
# diff: {'hor': {2}, 'ver': set()}
# score: 200
#
#
#
#
# idx: 56
# old: {'hor': [3], 'ver': []}
# smudge: (12, 13)
# new: {'hor': [3], 'ver': [15]}
# diff: {'hor': set(), 'ver': {15}}
# score: 15
#
#
#
#
# idx: 57
# old: {'hor': [], 'ver': [4]}
# smudge: (0, 8)
# new: {'hor': [5], 'ver': [4]}
# diff: {'hor': {5}, 'ver': set()}
# score: 500
#
#
#
#
# idx: 58
# old: {'hor': [], 'ver': [2]}
# smudge: (1, 8)
# new: {'hor': [3], 'ver': [2]}
# diff: {'hor': {3}, 'ver': set()}
# score: 300
#
#
#
#
# idx: 59
# old: {'hor': [4], 'ver': []}
# smudge: (12, 8)
# new: {'hor': [4], 'ver': [9]}
# diff: {'hor': set(), 'ver': {9}}
# score: 9
#
#
#
#
# idx: 60
# old: {'hor': [1], 'ver': []}
# smudge: (7, 8)
# new: {'hor': [1, 9], 'ver': []}
# diff: {'hor': {9}, 'ver': set()}
# score: 900
#
#
#
#
# idx: 61
# old: {'hor': [], 'ver': [1]}
# smudge: (0, 7)
# new: {'hor': [], 'ver': [1, 9]}
# diff: {'hor': set(), 'ver': {9}}
# score: 9
#
#
#
#
# idx: 62
# old: {'hor': [], 'ver': [1]}
# smudge: (1, 12)
# new: {'hor': [3], 'ver': [1]}
# diff: {'hor': {3}, 'ver': set()}
# score: 300
#
#
#
#
# idx: 63
# old: {'hor': [8], 'ver': []}
# smudge: (2, 4)
# new: {'hor': [8], 'ver': [9]}
# diff: {'hor': set(), 'ver': {9}}
# score: 9
#
#
#
#
# idx: 64
# old: {'hor': [], 'ver': [1]}
# smudge: (9, 5)
# new: {'hor': [], 'ver': [1, 6]}
# diff: {'hor': set(), 'ver': {6}}
# score: 6
#
#
#
#
# idx: 65
# old: {'hor': [], 'ver': [9]}
# smudge: (9, 1)
# new: {'hor': [], 'ver': [2, 9]}
# diff: {'hor': set(), 'ver': {2}}
# score: 2
#
#
#
#
# idx: 66
# old: {'hor': [], 'ver': [3]}
# smudge: (4, 0)
# new: {'hor': [], 'ver': [1]}
# diff: {'hor': set(), 'ver': {1}}
# score: 1
#
#
#
#
# idx: 67
# old: {'hor': [], 'ver': [7]}
# smudge: (0, 0)
# new: {'hor': [], 'ver': [1]}
# diff: {'hor': set(), 'ver': {1}}
# score: 1
#
#
#
#
# idx: 68
# old: {'hor': [2], 'ver': []}
# smudge: (9, 3)
# new: {'hor': [2, 10], 'ver': []}
# diff: {'hor': {10}, 'ver': set()}
# score: 1000
#
#
#
#
# idx: 69
# old: {'hor': [], 'ver': [6]}
# smudge: (0, 0)
# new: {'hor': [4], 'ver': [6]}
# diff: {'hor': {4}, 'ver': set()}
# score: 400
#
#
#
#
# idx: 70
# old: {'hor': [], 'ver': [14]}
# smudge: (12, 11)
# new: {'hor': [14], 'ver': [14]}
# diff: {'hor': {14}, 'ver': set()}
# score: 1400
#
#
#
#
# idx: 71
# old: {'hor': [], 'ver': [2]}
# smudge: (4, 5)
# new: {'hor': [], 'ver': [2, 6]}
# diff: {'hor': set(), 'ver': {6}}
# score: 6
#
#
#
#
# idx: 72
# old: {'hor': [11], 'ver': []}
# smudge: (1, 9)
# new: {'hor': [2, 11], 'ver': []}
# diff: {'hor': {2}, 'ver': set()}
# score: 200
#
#
#
#
# idx: 73
# old: {'hor': [2], 'ver': []}
# smudge: (8, 0)
# new: {'hor': [2], 'ver': [3]}
# diff: {'hor': set(), 'ver': {3}}
# score: 3
#
#
#
#
# idx: 74
# old: {'hor': [], 'ver': [2]}
# smudge: (2, 6)
# new: {'hor': [], 'ver': [2, 9]}
# diff: {'hor': set(), 'ver': {9}}
# score: 9
#
#
#
#
# idx: 75
# old: {'hor': [], 'ver': [13]}
# smudge: (11, 3)
# new: {'hor': [], 'ver': [4, 13]}
# diff: {'hor': set(), 'ver': {4}}
# score: 4
#
#
#
#
# idx: 76
# old: {'hor': [], 'ver': [15]}
# smudge: (2, 8)
# new: {'hor': [3], 'ver': [15]}
# diff: {'hor': {3}, 'ver': set()}
# score: 300
#
#
#
#
# idx: 77
# old: {'hor': [8], 'ver': []}
# smudge: (0, 6)
# new: {'hor': [2, 8], 'ver': []}
# diff: {'hor': {2}, 'ver': set()}
# score: 200
#
#
#
#
# idx: 78
# old: {'hor': [10], 'ver': []}
# smudge: (4, 4)
# new: {'hor': [5, 10], 'ver': []}
# diff: {'hor': {5}, 'ver': set()}
# score: 500
#
#
#
#
# idx: 79
# old: {'hor': [], 'ver': [6]}
# smudge: (5, 13)
# new: {'hor': [], 'ver': [6, 14]}
# diff: {'hor': set(), 'ver': {14}}
# score: 14
#
#
#
#
# idx: 80
# old: {'hor': [], 'ver': [10]}
# smudge: (14, 4)
# new: {'hor': [], 'ver': [5, 10]}
# diff: {'hor': set(), 'ver': {5}}
# score: 5
#
#
#
#
# idx: 81
# old: {'hor': [], 'ver': [3]}
# smudge: (2, 7)
# new: {'hor': [7], 'ver': [3]}
# diff: {'hor': {7}, 'ver': set()}
# score: 700
#
#
#
#
# idx: 82
# old: {'hor': [], 'ver': [3]}
# smudge: (7, 7)
# new: {'hor': [], 'ver': [3, 11]}
# diff: {'hor': set(), 'ver': {11}}
# score: 11
#
#
#
#
# idx: 83
# old: {'hor': [4], 'ver': []}
# smudge: (12, 3)
# new: {'hor': [4], 'ver': [5]}
# diff: {'hor': set(), 'ver': {5}}
# score: 5
#
#
#
#
# idx: 84
# old: {'hor': [5], 'ver': []}
# smudge: (1, 4)
# new: {'hor': [2], 'ver': []}
# diff: {'hor': {2}, 'ver': set()}
# score: 200
#
#
#
#
# idx: 85
# old: {'hor': [1], 'ver': []}
# smudge: (2, 9)
# new: {'hor': [1], 'ver': [10]}
# diff: {'hor': set(), 'ver': {10}}
# score: 10
#
#
#
#
# idx: 86
# old: {'hor': [], 'ver': [1]}
# smudge: (12, 4)
# new: {'hor': [], 'ver': [1, 8]}
# diff: {'hor': set(), 'ver': {8}}
# score: 8
#
#
#
#
# idx: 87
# old: {'hor': [], 'ver': [1]}
# smudge: (8, 7)
# new: {'hor': [9], 'ver': [1]}
# diff: {'hor': {9}, 'ver': set()}
# score: 900
#
#
#
#
# idx: 88
# old: {'hor': [], 'ver': [2]}
# smudge: (0, 13)
# new: {'hor': [1], 'ver': [2]}
# diff: {'hor': {1}, 'ver': set()}
# score: 100
#
#
#
#
# idx: 89
# old: {'hor': [], 'ver': [15]}
# smudge: (7, 4)
# new: {'hor': [], 'ver': [7, 15]}
# diff: {'hor': set(), 'ver': {7}}
# score: 7
#
#
#
#
# idx: 90
# old: {'hor': [], 'ver': [9]}
# smudge: (2, 9)
# new: {'hor': [], 'ver': [11]}
# diff: {'hor': set(), 'ver': {11}}
# score: 11
#
#
#
#
# idx: 91
# old: {'hor': [1], 'ver': []}
# smudge: (5, 1)
# new: {'hor': [1], 'ver': [3]}
# diff: {'hor': set(), 'ver': {3}}
# score: 3
#
#
#
#
# idx: 92
# old: {'hor': [], 'ver': [1]}
# smudge: (2, 6)
# new: {'hor': [3], 'ver': [1]}
# diff: {'hor': {3}, 'ver': set()}
# score: 300
#
#
#
#
# idx: 93
# old: {'hor': [8], 'ver': []}
# smudge: (5, 4)
# new: {'hor': [8], 'ver': [7]}
# diff: {'hor': set(), 'ver': {7}}
# score: 7
#
#
#
#
# idx: 94
# old: {'hor': [], 'ver': [4]}
# smudge: (4, 11)
# new: {'hor': [], 'ver': [4, 12]}
# diff: {'hor': set(), 'ver': {12}}
# score: 12
#
#
#
#
# idx: 95
# old: {'hor': [10], 'ver': []}
# smudge: (15, 8)
# new: {'hor': [16], 'ver': []}
# diff: {'hor': {16}, 'ver': set()}
# score: 1600
#
#
#
#
# idx: 96
# old: {'hor': [], 'ver': [2]}
# smudge: (0, 5)
# new: {'hor': [], 'ver': [2, 10]}
# diff: {'hor': set(), 'ver': {10}}
# score: 10
#
#
#
#
# idx: 97
# old: {'hor': [1], 'ver': []}
# smudge: (15, 6)
# new: {'hor': [1], 'ver': [8]}
# diff: {'hor': set(), 'ver': {8}}
# score: 8
#
#
#
#
# idx: 98
# old: {'hor': [14], 'ver': []}
# smudge: (5, 15)
# new: {'hor': [7, 14], 'ver': []}
# diff: {'hor': {7}, 'ver': set()}
# score: 700
#
#
#
#
# idx: 99
# old: {'hor': [3], 'ver': []}
# smudge: (0, 2)
# new: {'hor': [1], 'ver': []}
# diff: {'hor': {1}, 'ver': set()}
# score: 100
#
#
#
# [1, 100, 200, 600, 700, 600, 200, 5, 6, 3, 700, 1, 800, 6, 9, 4, 1100, 400, 2, 800, 14, 1600, 300, 500, 1000, 6, 5, 7, 600, 700, 800, 13, 6, 200, 12, 1000, 6, 2, 2, 8, 1300, 2, 900, 6, 8, 4, 300, 1, 1400, 1000, 15, 700, 500, 300, 1100, 200, 15, 500, 300, 9, 900, 9, 300, 9, 6, 2, 1, 1, 1000, 400, 1400, 6, 200, 3, 9, 4, 300, 200, 500, 14, 5, 700, 11, 5, 200, 10, 8, 900, 100, 7, 11, 3, 300, 7, 12, 1600, 10, 8, 700, 100]
# 31539
